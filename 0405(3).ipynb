# %% [markdown]
# <a href="https://colab.research.google.com/github/choeuibin/--1/blob/main/0405(3).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## 관심자격1 : 종속
# ## 독립 : 강의결제, 교재결제, 메일수신
# ## sms 수신.

# %%
import pandas as pd 
import numpy as np

# %%
#!sudo apt-get install -y fonts-nanum
#!sudo fc-cache -fv
#!rm ~/.cache/matplotlib -rf

# %%
import matplotlib.pyplot as plt
plt.rc('font', family='NanumBarunGothic')

# %%
df = pd.read_excel("/content/drive/MyDrive/프로젝트2/new_member_marketing_1.xlsx")
df

# %%
df_lecture = pd.DataFrame(df.groupby("관심자격1")["강의결제"].value_counts())

# %%
df_lecture
# Out:
#                  강의결제
# 관심자격1      강의결제
# -          X      430
#            O      131
# ADsP       X      546
#            O      110
# AFIE       X       10
# ...               ...
# 파생투자권유자문인력 O      386
# 펀드투자권유대행인  X      656
#            O      181
# 펀드투자권유자문인력 X      423
#            O      180
#
# [107 rows x 1 columns]

# %%
df_text = pd.DataFrame(df.groupby("관심자격1")["교재결제"].value_counts())
df_text
# Out:
#                  교재결제
# 관심자격1      교재결제
# -          X      432
#            O      129
# ADsP       X      566
#            O       90
# AFIE       X       10
# ...               ...
# 파생투자권유자문인력 O      266
# 펀드투자권유대행인  X      679
#            O      158
# 펀드투자권유자문인력 X      459
#            O      144
#
# [106 rows x 1 columns]

# %%
df_mail = pd.DataFrame(df.groupby("관심자격1")["메일수신"].value_counts())
df_mail
# Out:
#                  메일수신
# 관심자격1      메일수신
# -          X      440
#            O      121
# ADsP       X      463
#            O      193
# AFIE       X        8
# ...               ...
# 파생투자권유자문인력 O      251
# 펀드투자권유대행인  X      483
#            O      354
# 펀드투자권유자문인력 X      424
#            O      179
#
# [108 rows x 1 columns]

# %%
df_sms = pd.DataFrame(df.groupby("관심자격1")["sms수신"].value_counts())
df_sms
# Out:
#                   sms수신
# 관심자격1      sms수신
# -          X        375
#            O        186
# ADsP       X        435
#            O        221
# AFIE       X          7
# ...                 ...
# 파생투자권유자문인력 X        369
# 펀드투자권유대행인  X        424
#            O        413
# 펀드투자권유자문인력 X        323
#            O        280
#
# [108 rows x 1 columns]

# %%
import matplotlib
matplotlib.rcParams['font.size'] = 10

# %%
counts = df_lecture.loc["전산세무회계"]
counts.plot(kind = "bar", title = "전산세무회계")
# Out:
# <Axes: title={'center': '전산세무회계'}, xlabel='강의결제'>

# %%
counts = df_text.loc["전산세무회계"]
counts.plot(kind = "bar", title = "전산세무회계")
# Out:
# <Axes: title={'center': '전산세무회계'}, xlabel='교재결제'>

# %%
counts = df_mail.loc["전산세무회계"]
counts.plot(kind = "bar", title = "전산세무회계")
# Out:
# <Axes: title={'center': '전산세무회계'}, xlabel='메일수신'>

# %%
counts = df_sms.loc["전산세무회계"]
counts.plot(kind = "bar", title = "전산세무회계")
# Out:
# <Axes: title={'center': '전산세무회계'}, xlabel='sms수신'>

# %%
counts = df_lecture.loc["신용분석사"]
counts.plot(kind = "bar", title = "신용분석사")
# Out:
# <Axes: title={'center': '신용분석사'}, xlabel='강의결제'>

# %%
counts = df_text.loc["신용분석사"]
counts.plot(kind = "bar", title = "신용분석사")
# Out:
# <Axes: title={'center': '신용분석사'}, xlabel='교재결제'>

# %%
counts = df_mail.loc["신용분석사"]
counts.plot(kind = "bar", title = "신용분석사")
# Out:
# <Axes: title={'center': '신용분석사'}, xlabel='메일수신'>

# %%
counts = df_sms.loc["신용분석사"]
counts.plot(kind = "bar", title = "신용분석사")
# Out:
# <Axes: title={'center': '신용분석사'}, xlabel='sms수신'>

# %%
counts = df_lecture.loc["투자자산운용사"]
counts.plot(kind = "bar", title = "투자자산운용사")
# Out:
# <Axes: title={'center': '투자자산운용사'}, xlabel='강의결제'>

# %%
counts = df_text.loc["투자자산운용사"]
counts.plot(kind = "bar", title = "투자자산운용사")
# Out:
# <Axes: title={'center': '투자자산운용사'}, xlabel='교재결제'>

# %%
counts = df_mail.loc["투자자산운용사"]
counts.plot(kind = "bar", title = "투자자산운용사")
# Out:
# <Axes: title={'center': '투자자산운용사'}, xlabel='메일수신'>

# %%
counts = df_sms.loc["투자자산운용사"]
counts.plot(kind = "bar", title = "투자자산운용사")
# Out:
# <Axes: title={'center': '투자자산운용사'}, xlabel='sms수신'>

# %%
counts = df_lecture.loc["자산관리사(은행FP)"]
counts.plot(kind = "bar", title = "자산관리사(은행FP)")
# Out:
# <Axes: title={'center': '자산관리사(은행FP)'}, xlabel='강의결제'>

# %%
counts = df_text.loc["자산관리사(은행FP)"]
counts.plot(kind = "bar", title = "자산관리사(은행FP)")
# Out:
# <Axes: title={'center': '자산관리사(은행FP)'}, xlabel='교재결제'>

# %%
counts = df_mail.loc["자산관리사(은행FP)"]
counts.plot(kind = "bar", title = "자산관리사(은행FP)")
# Out:
# <Axes: title={'center': '자산관리사(은행FP)'}, xlabel='메일수신'>

# %%
counts = df_sms.loc["자산관리사(은행FP)"]
counts.plot(kind = "bar", title = "자산관리사(은행FP)")
# Out:
# <Axes: title={'center': '자산관리사(은행FP)'}, xlabel='sms수신'>

# %%
counts = df_lecture.loc["외환전문역 1종"]
counts.plot(kind = "bar", title = "외환전문역 1종")
# Out:
# <Axes: title={'center': '외환전문역 1종'}, xlabel='강의결제'>

# %%
counts = df_text.loc["외환전문역 1종"]
counts.plot(kind = "bar", title = "외환전문역 1종")
# Out:
# <Axes: title={'center': '외환전문역 1종'}, xlabel='교재결제'>

# %%
counts = df_mail.loc["외환전문역 1종"]
counts.plot(kind = "bar", title = "외환전문역 1종")
# Out:
# <Axes: title={'center': '외환전문역 1종'}, xlabel='메일수신'>

# %%
counts = df_sms.loc["외환전문역 1종"]
counts.plot(kind = "bar", title = "외환전문역 1종")
# Out:
# <Axes: title={'center': '외환전문역 1종'}, xlabel='sms수신'>

# %%
counts = df_lecture.loc["AFPK"]
counts.plot(kind = "bar", title = "AFPK")
# Out:
# <Axes: title={'center': 'AFPK'}, xlabel='강의결제'>

# %%
counts = df_text.loc["AFPK"]
counts.plot(kind = "bar", title = "AFPK")
# Out:
# <Axes: title={'center': 'AFPK'}, xlabel='교재결제'>

# %%
counts = df_mail.loc["AFPK"]
counts.plot(kind = "bar", title = "AFPK")
# Out:
# <Axes: title={'center': 'AFPK'}, xlabel='메일수신'>

# %%
counts = df_sms.loc["AFPK"]
counts.plot(kind = "bar", title = "AFPK")
# Out:
# <Axes: title={'center': 'AFPK'}, xlabel='sms수신'>

# %%
counts = df_lecture.loc["경영지도사"]
counts.plot(kind = "bar", title = "경영지도사")
# Out:
# <Axes: title={'center': '경영지도사'}, xlabel='강의결제'>

# %%
counts = df_text.loc["경영지도사"]
counts.plot(kind = "bar", title = "경영지도사")
# Out:
# <Axes: title={'center': '경영지도사'}, xlabel='교재결제'>

# %%
counts = df_mail.loc["경영지도사"]
counts.plot(kind = "bar", title = "경영지도사")
# Out:
# <Axes: title={'center': '경영지도사'}, xlabel='메일수신'>

# %%
counts = df_sms.loc["경영지도사"]
counts.plot(kind = "bar", title = "경영지도사")
# Out:
# <Axes: title={'center': '경영지도사'}, xlabel='sms수신'>

# %%
counts = df_lecture.loc["CFA"]
counts.plot(kind = "bar", title = "CFA")
# Out:
# <Axes: title={'center': 'CFA'}, xlabel='강의결제'>

# %%
counts = df_text.loc["CFA"]
counts.plot(kind = "bar", title = "CFA")
# Out:
# <Axes: title={'center': 'CFA'}, xlabel='교재결제'>

# %%
counts = df_mail.loc["CFA"]
counts.plot(kind = "bar", title = "CFA")
# Out:
# <Axes: title={'center': 'CFA'}, xlabel='메일수신'>

# %%
counts = df_sms.loc["CFA"]
counts.plot(kind = "bar", title = "CFA")
# Out:
# <Axes: title={'center': 'CFA'}, xlabel='sms수신'>

# %%
counts = df_lecture.loc["펀드투자권유대행인"]
counts.plot(kind = "bar", title = "펀드투자권유대행인")
# Out:
# <Axes: title={'center': '펀드투자권유대행인'}, xlabel='강의결제'>

# %%
counts = df_text.loc["펀드투자권유대행인"]
counts.plot(kind = "bar", title = "펀드투자권유대행인")
# Out:
# <Axes: title={'center': '펀드투자권유대행인'}, xlabel='교재결제'>

# %%
counts = df_mail.loc["펀드투자권유대행인"]
counts.plot(kind = "bar", title = "펀드투자권유대행인")
# Out:
# <Axes: title={'center': '펀드투자권유대행인'}, xlabel='메일수신'>

# %%
counts = df_sms.loc["펀드투자권유대행인"]
counts.plot(kind = "bar", title = "펀드투자권유대행인")
# Out:
# <Axes: title={'center': '펀드투자권유대행인'}, xlabel='sms수신'>

# %%
counts = df_lecture.loc["파생투자권유자문인력"]
counts.plot(kind = "bar", title = "파생투자권유자문인력")
# Out:
# <Axes: title={'center': '파생투자권유자문인력'}, xlabel='강의결제'>

# %%
counts = df_text.loc["파생투자권유자문인력"]
counts.plot(kind = "bar", title = "파생투자권유자문인력")
# Out:
# <Axes: title={'center': '파생투자권유자문인력'}, xlabel='교재결제'>

# %%
counts = df_mail.loc["펀드투자권유대행인"]
counts.plot(kind = "bar", title = "펀드투자권유대행인")
# Out:
# <Axes: title={'center': '펀드투자권유대행인'}, xlabel='메일수신'>

# %%
counts = df_sms.loc["펀드투자권유대행인"]
counts.plot(kind = "bar", title = "펀드투자권유대행인")
# Out:
# <Axes: title={'center': '펀드투자권유대행인'}, xlabel='sms수신'>
